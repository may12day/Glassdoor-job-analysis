# %%
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome("C://Users//Mayank//Downloads//chromedriver.exe")

# %%
dataframe = pd.DataFrame(columns=["Title","Location","Company","Rating","Description"])

# %%
driver.get("https://www.glassdoor.co.in/Job/india-data-science-jobs-SRCH_IL.0,5_IN115_KO6,18_IP17.htm")

# %%
driver.implicitly_wait(4)

# %%
all_jobs = driver.find_elements_by_class_name('jl')

# %%
for job in all_jobs:

    result_html = job.get_attribute('innerHTML')
    soup = BeautifulSoup(result_html,'html.parser')

    try:
        company = soup.find("div",class_="jobHeader").text.replace('\n','')
    except:
        company = 'None'

    tit_len = len(company)

    try:
        location = soup.find(class_="subtle loc").text
    except:
        location = 'None'

    loc_len = location[0]

    try:
        title = soup.find('div', {'class' :'jobContainer'}).text[tit_len:]
        title = title[:title.index(loc_len)]
    except:
        title = 'None'

    try:
         rating = soup.find("span",class_="compactStars").text
    except:
        rating = 'None'

    sum_div = job.find_elements_by_class_name("jobHeader")[0]
    try:
        sum_div.click()
    except:
        close_button = driver.find_elements_by_class_name("ModalStyle__xBtn___34qya")[0]
        close_button.click()
        sum_div.click()

    job_desc = driver.find_element_by_class_name('jobDescriptionContent').text.replace('\n',' ')


    dataframe = dataframe.append({'Title':title,'Location':location,"Company":company,
                                  "Rating":rating,"Description":job_desc},
                                 ignore_index=True)

# %%
for i in range(1,131,5):
    if(i==1):
        driver.get("https://www.glassdoor.co.in/Job/india-data-science-jobs-SRCH_IL.0,5_IN115_KO6,18.htm")
    else:
        driver.get("https://www.glassdoor.co.in/Job/india-data-science-jobs-SRCH_IL.0,5_IN115_KO6,18_IP"+str(i)+".htm")
    driver.implicitly_wait(4)
    all_jobs = driver.find_elements_by_class_name('jl')

dataframe = dataframe.append({'Title':title,'Location':location,"Company":company,
                                  "Rating":rating,"Description":job_desc},
                                 ignore_index=True)

# %%
print(dataframe)
# Out:
#                                                  Title    Location  \
# 0                                         Data Analyst   Bengaluru
# 1                                     Sr. Data Analyst   Bengaluru
# 2    Senior Software Development Engineer in Test (...   Bengaluru
# 3                                      Sr Data Analyst   Bengaluru
# 4                                        Lead Engineer   Bengaluru
# 5                                      Sr. Manager DSA   Bengaluru
# 6                                    Sr Data Scientist   Bengaluru
# 7                                             Engineer   Bengaluru
# 8                              Data Science Researcher   Bengaluru
# 9                                 Data Science Analyst   Bengaluru
# 10                                        Data Analyst     Gurgaon
# 11                        Data Science (Jupyter/Azure       Mumbai
# 12                             Data Science Specialist   Bengaluru
# 13                                    Data Scientist –     Gurgaon
# 14                                Data Science Analyst   Bengaluru
# 15                                      Data Scientist   Hyderabad
# 16                              Analyst-Data Analytics     Chennai
# 17                                      Data Scientist   Bengaluru
# 18                                      Data Scientist      Mumbai
# 19                              Associate Data Analyst     Gurgaon
# 20                                  Quant Data Analyst       Noida
# 21                                      Data Analyst I   Bengaluru
# 22                                      Data Scientist   Bengaluru
# 23                              Data Science Developer   Bengaluru
# 24                                      Data Scientist     Chennai
# 25                                     Python Engineer   Bengaluru
# 26         Data Science Manager (NLP, Speech Engineer)     Gurgaon
# 27                               Data Science - Intern   Bengaluru
# 28                                       Data Engineer   Bengaluru
# 29             Data Scientist: Artificial Intelligence     Kolkata
# ..                                                 ...         ...
# 453                                     Data Scientist        Pune
# 454                                     Data Scientist        East
# 455                                     Data Scientist      Mumbai
# 456                                     Data Scientist   New Delhi
# 457                                     Data Scientist  Chandigarh
# 458                                     Data Scientist   Bengaluru
# 459                              Software Engineer III   Bengaluru
# 460                                     Data Scientist   Bengaluru
# 461                                     Data Scientist        Pune
# 462                                     Data Scientist      Mumbai
# 463  Data Science Expert - Machine learning enginee...   New Delhi
# 464                                    Program Manager   Bengaluru
# 465                                     Data Scientist      Mumbai
# 466                                     Data Scientist   Bengaluru
# 467                                  Magento Developer     Kolkata
# 468                                     Data Scientist   Bengaluru
# 469                                     Data Scientist     Gurgaon
# 470                                     Data Scientist     Chennai
# 471                                     Data Scientist   Bengaluru
# 472                                     Data Scientist   Bengaluru
# 473                                     Data Scientist     Gurgaon
# 474                                     Data Scientist      Mumbai
# 475                                     Data Scientist     Chennai
# 476                                     Data Scientist      Mumbai
# 477                                                      Bengaluru
# 478                                     Data Scientist   Bengaluru
# 479                                     Data Scientist   Bengaluru
# 480                                     Data Scientist      Mumbai
# 481                                     Data Scientist   Bengaluru
# 482                                     Data Scientist   Bengaluru
#
#                                Company Rating  \
# 0                               Target    4.0
# 1                               Target    4.0
# 2                             AutoGrid   None
# 3                               Target    4.0
# 4                               Target    4.0
# 5                               Target    4.0
# 6                               Target    4.0
# 7                               Target    4.0
# 8                                Shell    3.9
# 9                                  AIG    3.1
# 10                         GroundTruth   None
# 11                           Accenture    3.9
# 12                           Accenture    3.9
# 13                            Mobileum    3.5
# 14                                Dell    3.9
# 15                             Neustar   None
# 16                             Verizon    3.6
# 17                              Intuit    4.1
# 18                     Star TV Network    3.6
# 19              Fidelity International    3.5
# 20                            Barclays    3.8
# 21                             HP Inc.    4.1
# 22                          ExxonMobil    3.8
# 23                              Oracle    3.5
# 24                               Shell    3.9
# 25                            AutoGrid   None
# 26                  UnitedHealth Group    3.4
# 27                              zeotap   None
# 28                       GE Healthcare    3.9
# 29                                 IBM    3.7
# ..                                 ...    ...
# 453                   e-Zest Solutions    4.1
# 454                               PSCU   None
# 455                     NOVIQUE HEALTH   None
# 456       Saffron Consultancy Services   None
# 457                         DataToBiz2   None
# 458                    Aptus Data LAbs    2.6
# 459                            Neustar   None
# 460                   Vindhya Infotech   None
# 461                    Foghorn Systems   None
# 462                WNS Global Services   None
# 463          Crescendo Global Services    4.9
# 464                       Y Media Labs   None
# 465                         TEQNirvana    3.9
# 466                        Diamondpick    3.7
# 467                           Dygitech    4.0
# 468                        Zeta Global   None
# 469                  Profisor Services    5.0
# 470               Applied Data Finance   None
# 471                           Conduent    2.6
# 472                  EdgeVerve Systems    3.5
# 473                        Engineer.ai   None
# 474  Institute of Information Security    1.0
# 475             Magna Infotech (India)   None
# 476                  eliterecruitments   None
# 477                           AutoGrid   None
# 478                              Chase   None
# 479                                BDB   None
# 480                           big tree   None
# 481             ITC Infotech India Ltd    3.2
# 482                   WeRecruit Talent   None
#
#                                            Description
# 0    Description:  About us:  Target is an iconic b...
# 1    Description:  Education/Experience: Bachelors ...
# 2    Description:  Education/Experience: Bachelors ...
# 3    Description:  Education/Experience: Bachelors ...
# 4    Description:  Education/Experience: Bachelors ...
# 5    Description:  Education/Experience: Bachelors ...
# 6    Description:  Education/Experience: Bachelors ...
# 7    Description:  Education/Experience: Bachelors ...
# 8    Description:  Education/Experience: Bachelors ...
# 9    Description:  Education/Experience: Bachelors ...
# 10   Description:  Education/Experience: Bachelors ...
# 11   Description:  Education/Experience: Bachelors ...
# 12   Description:  Education/Experience: Bachelors ...
# 13   Description:  Education/Experience: Bachelors ...
# 14   Description:  Education/Experience: Bachelors ...
# 15   Description:  Education/Experience: Bachelors ...
# 16   Description:  Education/Experience: Bachelors ...
# 17   Description:  Education/Experience: Bachelors ...
# 18   Description:  Education/Experience: Bachelors ...
# 19   Description:  Education/Experience: Bachelors ...
# 20   Description:  Education/Experience: Bachelors ...
# 21   Description:  Education/Experience: Bachelors ...
# 22   Description:  Education/Experience: Bachelors ...
# 23   Description:  Education/Experience: Bachelors ...
# 24   Description:  Education/Experience: Bachelors ...
# 25   Description:  Education/Experience: Bachelors ...
# 26   Description:  Education/Experience: Bachelors ...
# 27   Description:  Education/Experience: Bachelors ...
# 28   Description:  Education/Experience: Bachelors ...
# 29   Description:  Education/Experience: Bachelors ...
# ..                                                 ...
# 453  pyspark Tensorflow Big Data We are looking for...
# 454  pyspark Tensorflow Big Data We are looking for...
# 455  pyspark Tensorflow Big Data We are looking for...
# 456  pyspark Tensorflow Big Data We are looking for...
# 457  pyspark Tensorflow Big Data We are looking for...
# 458  pyspark Tensorflow Big Data We are looking for...
# 459  pyspark Tensorflow Big Data We are looking for...
# 460  pyspark Tensorflow Big Data We are looking for...
# 461  pyspark Tensorflow Big Data We are looking for...
# 462  pyspark Tensorflow Big Data We are looking for...
# 463  pyspark Tensorflow Big Data We are looking for...
# 464  pyspark Tensorflow Big Data We are looking for...
# 465  pyspark Tensorflow Big Data We are looking for...
# 466  pyspark Tensorflow Big Data We are looking for...
# 467  pyspark Tensorflow Big Data We are looking for...
# 468  pyspark Tensorflow Big Data We are looking for...
# 469  pyspark Tensorflow Big Data We are looking for...
# 470  pyspark Tensorflow Big Data We are looking for...
# 471  pyspark Tensorflow Big Data We are looking for...
# 472  pyspark Tensorflow Big Data We are looking for...
# 473  pyspark Tensorflow Big Data We are looking for...
# 474  pyspark Tensorflow Big Data We are looking for...
# 475  pyspark Tensorflow Big Data We are looking for...
# 476  pyspark Tensorflow Big Data We are looking for...
# 477  pyspark Tensorflow Big Data We are looking for...
# 478  pyspark Tensorflow Big Data We are looking for...
# 479  pyspark Tensorflow Big Data We are looking for...
# 480  pyspark Tensorflow Big Data We are looking for...
# 481  pyspark Tensorflow Big Data We are looking for...
# 482  pyspark Tensorflow Big Data We are looking for...
#
# [483 rows x 5 columns]

# %%
dataframe.to_csv("datascience.csv",index=False)

# %%
pp = pd.read_csv('datascience.csv')

# %%
print(pp)
